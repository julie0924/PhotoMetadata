# %%
import numpy as np
import pandas as pd
import json
import os

# %%
ori = pd.read_csv('fromjson_photos.csv')
photos = pd.read_csv('fromcsv_photos.csv')

# %%
ori.tail()
# Out:
#                    file_name orientation
# 6746  20220825_SD05_6957.JPG     portait
# 6747  20220825_SD05_6958.JPG     portait
# 6748  20220825_SD05_6960.JPG     portait
# 6749  20220825_SD05_6963.JPG     portait
# 6750  20220825_SD05_6967.JPG     portait

# %%
photos.tail()
# Out:
#       jpg_id               file_name monkey_group sd_card  date_taken
# 6746    6746  20220825_SD05_6957.JPG  Instigators    SD05  2022-08-25
# 6747    6747  20220825_SD05_6958.JPG  Instigators    SD05  2022-08-25
# 6748    6748  20220825_SD05_6960.JPG  Instigators    SD05  2022-08-25
# 6749    6749  20220825_SD05_6963.JPG  Instigators    SD05  2022-08-25
# 6750    6750  20220825_SD05_6967.JPG  Instigators    SD05  2022-08-25

# %%
photos['orientation'] = ori['orientation']
photos.tail()
# Out:
#       jpg_id               file_name monkey_group sd_card  date_taken  \
# 6746    6746  20220825_SD05_6957.JPG  Instigators    SD05  2022-08-25
# 6747    6747  20220825_SD05_6958.JPG  Instigators    SD05  2022-08-25
# 6748    6748  20220825_SD05_6960.JPG  Instigators    SD05  2022-08-25
# 6749    6749  20220825_SD05_6963.JPG  Instigators    SD05  2022-08-25
# 6750    6750  20220825_SD05_6967.JPG  Instigators    SD05  2022-08-25
#
#      orientation
# 6746     portait
# 6747     portait
# 6748     portait
# 6749     portait
# 6750     portait

# %%
# Original dataframe
original_columns = ['jpg_id', 'file_name', 'monkey_group','sd_card','date_taken','orientation']

# New column order
new_columns = ['jpg_id', 'file_name', 'sd_card','date_taken','monkey_group','orientation']

# Reorder columns
photos = photos[new_columns]

photos.tail()
# Out:
#       jpg_id               file_name sd_card  date_taken monkey_group  \
# 6746    6746  20220825_SD05_6957.JPG    SD05  2022-08-25  Instigators
# 6747    6747  20220825_SD05_6958.JPG    SD05  2022-08-25  Instigators
# 6748    6748  20220825_SD05_6960.JPG    SD05  2022-08-25  Instigators
# 6749    6749  20220825_SD05_6963.JPG    SD05  2022-08-25  Instigators
# 6750    6750  20220825_SD05_6967.JPG    SD05  2022-08-25  Instigators
#
#      orientation
# 6746     portait
# 6747     portait
# 6748     portait
# 6749     portait
# 6750     portait

# %%
photos['contents'] = 'monkey'
photos.tail(7)
# Out:
#       jpg_id               file_name sd_card  date_taken monkey_group  \
# 6744    6744  20220825_SD05_6952.JPG    SD05  2022-08-25  Instigators
# 6745    6745  20220825_SD05_6954.JPG    SD05  2022-08-25  Instigators
# 6746    6746  20220825_SD05_6957.JPG    SD05  2022-08-25  Instigators
# 6747    6747  20220825_SD05_6958.JPG    SD05  2022-08-25  Instigators
# 6748    6748  20220825_SD05_6960.JPG    SD05  2022-08-25  Instigators
# 6749    6749  20220825_SD05_6963.JPG    SD05  2022-08-25  Instigators
# 6750    6750  20220825_SD05_6967.JPG    SD05  2022-08-25  Instigators
#
#      orientation contents
# 6744     portait   monkey
# 6745     portait   monkey
# 6746     portait   monkey
# 6747     portait   monkey
# 6748     portait   monkey
# 6749     portait   monkey
# 6750     portait   monkey

# %% [markdown]
# # Toy Table

# %%
coord = pd.read_csv('fromjson_coord.csv')
toys = pd.read_csv('fromcsv_toy.csv')

# %%
coord.head()
# Out:
#                 file_name bndbox_name  \
# 0  20220308_SD02_2923.JPG   DF2I_Face
# 1  20220308_SD02_2923.JPG   DF2I_Body
# 2  20220308_SD02_2924.JPG   DF2I_Face
# 3  20220308_SD02_2924.JPG   DF2I_Body
# 4  20220308_SD02_2946.JPG   7124_Body
#
#                                          coordinates
# 0  (0.36186799999999997, 0.0028209999999999997, 0...
# 1                          (0.0, 0.0, 0.954399, 1.0)
# 2  (0.34282199999999996, 0.0, 0.8845649999999999,...
# 3  (0.0, 0.0028209999999999997, 0.975560999999999...
# 4      (0.002116, 0.0, 0.387262, 0.7334269999999999)

# %%
toys.head()
# Out:
#    toy_id  jpg_id         toys
# 0       0      38      Unknown
# 1       1      60  Dental Star
# 2       2      79     Dumbbell
# 3       3     163      Grenade
# 4       4     163      Grenade
